# %%
import pandas as pd
import numpy as np

# %%
# 문화체육관광부_정책브리핑_위클리공감
weekly = pd.read_csv('./Finall Project/문화체육관광부_정책브리핑_위클리공감_20221026.csv', encoding='CP949')
# Out:
# C:\Users\helen\AppData\Local\Temp\ipykernel_9772\1609614598.py:1: DtypeWarning: Columns (7,8,16,20,24,25,26,33,34,35,37,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   weekly = pd.read_csv('./Finall Project/문화체육관광부_정책브리핑_위클리공감_20221026.csv', encoding='CP949')

# %%
weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27372 entries, 0 to 27371
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   뉴스아이디           27372 non-null  object
#  1   섹션아이디           27363 non-null  object
#  2   중요도             27372 non-null  int64
#  3   사용여부            27372 non-null  object
#  4   에이치티엠엘(HTML)여부  27372 non-null  object
#  5   공지여부            0 non-null      float64
#  6   서브타이틀1          2700 non-null   object
#  7   서브타이틀2          1225 non-null   object
#  8   서브타이틀3          1224 non-null   object
#  9   메인제목            27370 non-null  object
#  10  내용              25563 non-null  object
#  11  승인아이디           25027 non-null  object
#  12  승인일             25438 non-null  object
#  13  예약일             25438 non-null  object
#  14  대표이미지아이디        10335 non-null  float64
#  15  썸네일아이디          6287 non-null   float64
#  16  키워드             1681 non-null   object
# ...

# %%
weekly[['뉴스아이디', '중요도', '사용여부', '조회수', '공지여부', '이북번호', '승인아이디', 
        '대표이미지아이디', '썸네일아이디', '추천기사여부', '호수','기자명']]
# Out:
#                   뉴스아이디  중요도 사용여부     조회수  공지여부  이북번호     승인아이디     대표이미지아이디  \
# 0             148683898    0   승인  3038.0   NaN   NaN  55001990  144181999.0
# 1             148683061    0   승인  2950.0   NaN   NaN       109  144174978.0
# 2             148683062    0   승인  3550.0   NaN   NaN       109  144174983.0
# 3             148683063    0   승인  1983.0   NaN   NaN       109  144174987.0
# 4             148683066    0   승인  2466.0   NaN   NaN       109  144174999.0
# ...                 ...  ...  ...     ...   ...   ...       ...          ...
# 27367  GAJqQKkosDDGJ000    0   승인     NaN   NaN   NaN       NaN          NaN
# 27368  GAJr70RIDDGJM000    0   승인   296.0   NaN  1889       NaN          NaN
# 27369  GAJqlJSU8DDGJ000    0   승인     9.0   NaN  1881       NaN          NaN
# 27370  GAJpOpCoIDDGJ000    0   승인   353.0   NaN  1870       NaN          NaN
# 27371  GAJrmOcmsDDGJ000    0   승인     7.0   NaN  1887       NaN          NaN
#
#             썸네일아이디 추천기사여부   호수  기자명
# ...

# %%
# 문화체육관광부_정책브리핑_이벤트
event = pd.read_csv('./Finall Project/문화체육관광부_정책브리핑_이벤트_20221027.csv', encoding='cp949')
event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3869 entries, 0 to 3868
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이벤트아이디  3869 non-null   int64
#  1   이벤트제목   3869 non-null   object
#  2   이벤트주소   3868 non-null   object
#  3   타겟구분    3869 non-null   object
#  4   내용      3869 non-null   object
#  5   사용여부    3869 non-null   object
#  6   등록일     3869 non-null   object
#  7   시작일     3868 non-null   object
#  8   종료일     3868 non-null   object
#  9   적용시작일   3867 non-null   object
#  10  적용종료일   3867 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 332.6+ KB

# %%
event[['이벤트아이디','타겟구분', '사용여부']]
# Out:
#       이벤트아이디 타겟구분 사용여부
# 0          2   링크  미사용
# 1          3   링크  미사용
# 2          4   링크  미사용
# 3          5   링크  미사용
# 4          6   링크  미사용
# ...      ...  ...  ...
# 3864    3887   새창   사용
# 3865    3888   새창   사용
# 3866    3889   새창   사용
# 3867    3890   새창   사용
# 3868    3891   새창   사용
#
# [3869 rows x 3 columns]

# %%
기사글번호, 부모기사글번호, 사진기제작자코드, 사진기기기종류명, 찰영지명, 
역사일자, 이력년월(사진기사 이력),  부가정보, 정렬순서, 추천수, 조회수, 날짜표시구분

# %%
# 문화체육관광부_정책브리핑_포토
photo = pd.read_csv('./Finall Project/문화체육관광부_정책브리핑_포토_10_21_2021.csv', encoding='cp949')
photo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33406 entries, 0 to 33405
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기사글번호       33406 non-null  int64
#  1   주제코드        33406 non-null  object
#  2   소속코드        33406 non-null  object
#  3   부모기사글번호     33406 non-null  int64
#  4   기사글제목       33406 non-null  object
#  5   기사글부제목      2788 non-null   object
#  6   기사글내용       20618 non-null  object
#  7   기사글태그정보     19780 non-null  object
#  8   기자기수아이디     120 non-null    object
#  9   사진기제작자코드    17247 non-null  object
#  10  사진기기기종류명    17067 non-null  object
#  11  촬영지역명       22262 non-null  float64
#  12  촬영지역상세주소    22214 non-null  object
#  13  촬영날짜정보      22262 non-null  object
#  14  촬영행위자명      21674 non-null  object
#  15  썸네일저장주소     23070 non-null  object
#  16  역사일자        11732 non-null  float64
#  17  이력년월        11732 non-null  float64
#  18  대표사진내용      7231 non-null   object
# ...

# %%
photo[['기사글번호', '부모기사글번호', '사진기제작자코드', '사진기기기종류명', '촬영지역명', 
       '역사일자', '이력년월', '부가정보', '정렬순서', '추천수', '조회수', '날짜표시구분']]
# Out:
#        기사글번호  부모기사글번호 사진기제작자코드 사진기기기종류명  촬영지역명  역사일자      이력년월  부가정보  정렬순서  \
# 0          8        0      ETC      etc    9.0  19.0  201110.0   NaN     0
# 1          9        0      ETC      etc    1.0  17.0  201110.0   NaN     0
# 2         10        0      ETC      etc   16.0  18.0  201110.0   NaN     0
# 3         13        0      ETC     캐논 등    1.0   NaN       NaN   NaN     0
# 4         22        0      ETC     캐논 등    9.0   NaN       NaN   NaN     0
# ...      ...      ...      ...      ...    ...   ...       ...   ...   ...
# 33401  44327        0      NaN      NaN    9.0   NaN       NaN   NaN     1
# 33402  44328        0      NaN      NaN    8.0   NaN       NaN   NaN     1
# 33403  44329        0      NaN      NaN    8.0   NaN       NaN   NaN     1
# 33404  44330        0      NaN      NaN   18.0   NaN       NaN   NaN     1
# 33405  44331        0      NaN      NaN    1.0   NaN       NaN   NaN     1
#
#        추천수   조회수  날짜표시구분
# 0       45  2159     NaN
# ...

# %%
photo[['기사글분류코드']]
# Out:
#       기사글분류코드
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 33401     NaN
# 33402     NaN
# 33403     NaN
# 33404     NaN
# 33405     NaN
#
# [33406 rows x 1 columns]
